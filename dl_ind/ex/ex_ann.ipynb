# %%
import numpy as np
import pandas as pd
import seaborn as sn
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("../csv/customer_churn.csv")
df.drop(["customerID"], axis="columns", inplace=True)
df.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 561     Male              0     Yes         No       3          Yes
# 6389  Female              0     Yes        Yes      58          Yes
# 6092  Female              0     Yes         No      72          Yes
# 3800  Female              0      No        Yes      66          Yes
# 4138  Female              0      No         No       1          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 561            Yes              No  No internet service  No internet service
# 6389            No              No  No internet service  No internet service
# 6092           Yes     Fiber optic                  Yes                  Yes
# 3800           Yes     Fiber optic                  Yes                   No
# 4138            No     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 561   No internet service  No internet service  No internet service
# 6389  No internet service  No internet service  No internet service
# 6092                  Yes                  Yes                   No
# 3800                  Yes                  Yes                   No
# 4138                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 561   No internet service  Month-to-month              Yes
# 6389  No internet service        Two year               No
# 6092                   No        Two year              Yes
# 3800                   No        Two year              Yes
# 4138                   No  Month-to-month              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 561                Mailed check           23.60        89.05    No
# 6389    Credit card (automatic)           19.55      1079.65    No
# 6092  Bank transfer (automatic)           94.25      6849.75    No
# 3800    Credit card (automatic)           90.95      5930.05    No
# 4138           Electronic check           85.45        85.45   Yes

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df[df.TotalCharges == ' '].shape, df.shape
# Out:
# ((11, 20), (7043, 20))

# %%
df1 = df[df.TotalCharges != ' ']
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
df1.head()
# Out:
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2570494074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges = pd.to_numeric(df1.TotalCharges)
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
def print_obj_colls(df):
    for col in df:
        if df[col].dtypes == "object":
            print(f"{col}, {df[col].unique()}")

# %%
print_obj_colls(df1)
# Out:
# gender, ['Female' 'Male']
# Partner, ['Yes' 'No']
# Dependents, ['No' 'Yes']
# PhoneService, ['No' 'Yes']
# MultipleLines, ['No phone service' 'No' 'Yes']
# InternetService, ['DSL' 'Fiber optic' 'No']
# OnlineSecurity, ['No' 'Yes' 'No internet service']
# OnlineBackup, ['Yes' 'No' 'No internet service']
# DeviceProtection, ['No' 'Yes' 'No internet service']
# TechSupport, ['No' 'Yes' 'No internet service']
# StreamingTV, ['No' 'Yes' 'No internet service']
# StreamingMovies, ['No' 'Yes' 'No internet service']
# Contract, ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling, ['Yes' 'No']
# PaymentMethod, ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn, ['No' 'Yes']

# %%
tenure_churn_no = df1[df1.Churn=='No'].tenure
tenure_churn_yes = df1[df1.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")

plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['yellow','red'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
df1.replace('No phone service', 'No', inplace=True)
df1.replace('No internet service', 'No', inplace=True)

print_obj_colls(df1)
# Out:
# gender, ['Female' 'Male']
# Partner, ['Yes' 'No']
# Dependents, ['No' 'Yes']
# PhoneService, ['No' 'Yes']
# MultipleLines, ['No' 'Yes']
# InternetService, ['DSL' 'Fiber optic' 'No']
# OnlineSecurity, ['No' 'Yes']
# OnlineBackup, ['Yes' 'No']
# DeviceProtection, ['No' 'Yes']
# TechSupport, ['No' 'Yes']
# StreamingTV, ['No' 'Yes']
# StreamingMovies, ['No' 'Yes']
# Contract, ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling, ['Yes' 'No']
# PaymentMethod, ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn, ['No' 'Yes']
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\431680739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No phone service', 'No', inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\431680739.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace=True)

# %%
df1.sample(5)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6994  Female              0     Yes        Yes      43          Yes
# 1033  Female              0     Yes         No      62          Yes
# 6528    Male              0     Yes        Yes      70          Yes
# 1278    Male              0     Yes        Yes      36           No
# 1729    Male              0     Yes         No      64          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 6994           Yes              No             No           No
# 1033           Yes              No             No           No
# 6528            No              No             No           No
# 1278            No             DSL            Yes           No
# 1729           Yes     Fiber optic            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 6994               No          No          No              No  One year
# 1033               No          No          No              No  Two year
# 6528               No          No          No              No  Two year
# 1278              Yes         Yes         Yes             Yes  One year
# 1729              Yes          No          No              No  One year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 6994              Yes  Bank transfer (automatic)           24.45
# 1033               No  Bank transfer (automatic)           23.65
# 6528               No    Credit card (automatic)           20.35
# 1278               No    Credit card (automatic)           60.70
# 1729               No  Bank transfer (automatic)           89.45
#
#       TotalCharges Churn
# 6994        993.15    No
# 1033       1416.75    No
# 6528       1458.10    No
# 1278       2234.55    No
# 1729       5692.65    No

# %%
yes_and_no_cols = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                   'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn']

for col in yes_and_no_cols:
    df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
    df1[col] = df1[col].astype(np.uint8)

df1.replace({"Male" : 1, "Female" : 0}, inplace=True)
df1["gender"] = df1["gender"].astype(np.uint8)
df1.sample(5)
# Out:
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col].replace({"Yes" : 1, "No" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[col] = df1[col].astype(np.uint8)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace({"Male" : 1, "Female" : 0}, inplace=True)
# C:\Users\Артём\AppData\Local\Temp\ipykernel_14292\2167301568.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["gender"] = df1["gender"].astype(np.uint8)
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2958       0              0        0           0       1             1
# 3964       0              0        1           1      68             1
# 2600       0              0        0           0       1             1
# 5515       0              0        1           1      18             1
# 2510       1              0        0           0       1             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 2958              0              No               0             0
# 3964              1     Fiber optic               1             0
# 2600              0     Fiber optic               0             0
# 5515              0              No               0             0
# 2510              1     Fiber optic               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 2958                 0            0            0                0
# 3964                 1            1            1                1
# 2600                 0            0            0                0
# 5515                 0            0            0                0
# 2510                 0            0            0                0
#
#             Contract  PaperlessBilling            PaymentMethod  \
# 2958  Month-to-month                 0  Credit card (automatic)
# 3964        Two year                 0  Credit card (automatic)
# 2600  Month-to-month                 0         Electronic check
# 5515        Two year                 0             Mailed check
# 2510  Month-to-month                 1             Mailed check
#
#       MonthlyCharges  TotalCharges  Churn
# 2958           19.55         19.55      0
# 3964          111.75       7511.30      0
# 2600           70.10         70.10      0
# 5515           19.35        309.25      0
# 2510           74.25         74.25      1

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService', 'Contract', 'PaymentMethod'])
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 2789       0              0        0           0      24             1
# 832        0              0        1           1      70             1
# 6814       0              1        1           0      57             1
# 101        0              0        1           1       1             1
# 4501       0              0        0           0      39             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 2789              1               0             0                 1  ...
# 832               0               1             1                 1  ...
# 6814              1               0             1                 1  ...
# 101               0               0             0                 0  ...
# 4501              0               0             0                 0  ...
#
#       InternetService_DSL  InternetService_Fiber optic  InternetService_No  \
# 2789                False                         True               False
# 832                  True                        False               False
# 6814                False                         True               False
# 101                 False                        False                True
# 4501                False                        False                True
#
#       Contract_Month-to-month  Contract_One year  Contract_Two year  \
# 2789                     True              False              False
# 832                     False               True              False
# 6814                     True              False              False
# 101                      True              False              False
# 4501                    False              False               True
#
#       PaymentMethod_Bank transfer (automatic)  \
# 2789                                    False
# 832                                     False
# 6814                                    False
# 101                                     False
# 4501                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 2789                                   True                           False
# 832                                    True                           False
# 6814                                   True                           False
# 101                                   False                            True
# 4501                                   True                           False
#
#       PaymentMethod_Mailed check
# 2789                       False
# 832                        False
# 6814                       False
# 101                        False
# 4501                       False
#
# [5 rows x 27 columns]

# %%
df2.drop(['PaymentMethod_Mailed check', 'Contract_Two year', 'InternetService_No'], axis='columns', inplace=True)
df2.dtypes
# Out:
# gender                                       uint8
# SeniorCitizen                                int64
# Partner                                      uint8
# Dependents                                   uint8
# tenure                                       int64
# PhoneService                                 uint8
# MultipleLines                                uint8
# OnlineSecurity                               uint8
# OnlineBackup                                 uint8
# DeviceProtection                             uint8
# TechSupport                                  uint8
# StreamingTV                                  uint8
# StreamingMovies                              uint8
# PaperlessBilling                             uint8
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        uint8
# InternetService_DSL                           bool
# InternetService_Fiber optic                   bool
# Contract_Month-to-month                       bool
# Contract_One year                             bool
# PaymentMethod_Bank transfer (automatic)       bool
# PaymentMethod_Credit card (automatic)         bool
# PaymentMethod_Electronic check                bool
# dtype: object

# %%
df2.corr()
# Out:
#                                            gender  SeniorCitizen   Partner  \
# gender                                   1.000000      -0.001819 -0.001379
# SeniorCitizen                           -0.001819       1.000000  0.016957
# Partner                                 -0.001379       0.016957  1.000000
# Dependents                               0.010349      -0.210550  0.452269
# tenure                                   0.005285       0.015683  0.381912
# PhoneService                            -0.007515       0.008392  0.018397
# MultipleLines                           -0.008883       0.142996  0.142561
# OnlineSecurity                          -0.016328      -0.038576  0.143346
# OnlineBackup                            -0.013093       0.066663  0.141849
# DeviceProtection                        -0.000807       0.059514  0.153556
# TechSupport                             -0.008507      -0.060577  0.120206
# StreamingTV                             -0.007124       0.105445  0.124483
# StreamingMovies                         -0.010105       0.119842  0.118108
# PaperlessBilling                        -0.011902       0.156258 -0.013957
# MonthlyCharges                          -0.013779       0.219874  0.097825
# TotalCharges                             0.000048       0.102411  0.319072
# Churn                                   -0.008545       0.150541 -0.149982
# InternetService_DSL                      0.007584      -0.108276 -0.001043
# InternetService_Fiber optic             -0.011189       0.254923  0.001235
# Contract_Month-to-month                 -0.003251       0.137752 -0.280202
# Contract_One year                        0.007755      -0.046491  0.083067
# PaymentMethod_Bank transfer (automatic) -0.015973      -0.016235  0.111406
# PaymentMethod_Credit card (automatic)    0.001632      -0.024359  0.082327
# PaymentMethod_Electronic check           0.000844       0.171322 -0.083207
#
#                                          Dependents    tenure  PhoneService  \
# gender                                     0.010349  0.005285     -0.007515
# SeniorCitizen                             -0.210550  0.015683      0.008392
# Partner                                    0.452269  0.381912      0.018397
# Dependents                                 1.000000  0.163386     -0.001078
# tenure                                     0.163386  1.000000      0.007877
# PhoneService                              -0.001078  0.007877      1.000000
# MultipleLines                             -0.024307  0.332399      0.279530
# OnlineSecurity                             0.080786  0.328297     -0.091676
# OnlineBackup                               0.023639  0.361138     -0.052133
# DeviceProtection                           0.013900  0.361520     -0.070076
# TechSupport                                0.063053  0.325288     -0.095138
# StreamingTV                               -0.016499  0.280264     -0.021383
# StreamingMovies                           -0.038375  0.285402     -0.033477
# PaperlessBilling                          -0.110131  0.004823      0.016696
# MonthlyCharges                            -0.112343  0.246862      0.248033
# TotalCharges                               0.064653  0.825880      0.113008
# Churn                                     -0.163128 -0.354049      0.011691
# InternetService_DSL                        0.051593  0.013786     -0.452255
# InternetService_Fiber optic               -0.164101  0.017930      0.290183
# Contract_Month-to-month                   -0.229715 -0.649346     -0.001243
# Contract_One year                          0.069222  0.202338     -0.003142
# PaymentMethod_Bank transfer (automatic)    0.052369  0.243822      0.008271
# PaymentMethod_Credit card (automatic)      0.061134  0.232800     -0.006916
# PaymentMethod_Electronic check            -0.149274 -0.210197      0.002747
#
#                                          MultipleLines  OnlineSecurity  \
# gender                                       -0.008883       -0.016328
# SeniorCitizen                                 0.142996       -0.038576
# Partner                                       0.142561        0.143346
# Dependents                                   -0.024307        0.080786
# tenure                                        0.332399        0.328297
# PhoneService                                  0.279530       -0.091676
# MultipleLines                                 1.000000        0.098592
# OnlineSecurity                                0.098592        1.000000
# OnlineBackup                                  0.202228        0.283285
# DeviceProtection                              0.201733        0.274875
# TechSupport                                   0.100421        0.354458
# StreamingTV                                   0.257804        0.175514
# StreamingMovies                               0.259194        0.187426
# PaperlessBilling                              0.163746       -0.004051
# MonthlyCharges                                0.490912        0.296447
# TotalCharges                                  0.469042        0.412619
# Churn                                         0.040033       -0.171270
# InternetService_DSL                          -0.200318        0.320343
# InternetService_Fiber optic                   0.366420       -0.030506
# Contract_Month-to-month                      -0.088558       -0.246844
# Contract_One year                            -0.003594        0.100658
# PaymentMethod_Bank transfer (automatic)       0.075429        0.094366
# PaymentMethod_Credit card (automatic)         0.060319        0.115473
# PaymentMethod_Electronic check                0.083583       -0.112295
#
#                                          OnlineBackup  DeviceProtection  ...  \
# gender                                      -0.013093         -0.000807  ...
# SeniorCitizen                                0.066663          0.059514  ...
# Partner                                      0.141849          0.153556  ...
# Dependents                                   0.023639          0.013900  ...
# tenure                                       0.361138          0.361520  ...
# PhoneService                                -0.052133         -0.070076  ...
# MultipleLines                                0.202228          0.201733  ...
# OnlineSecurity                               0.283285          0.274875  ...
# OnlineBackup                                 1.000000          0.303058  ...
# DeviceProtection                             0.303058          1.000000  ...
# TechSupport                                  0.293705          0.332850  ...
# StreamingTV                                  0.281601          0.389924  ...
# StreamingMovies                              0.274523          0.402309  ...
# PaperlessBilling                             0.127056          0.104079  ...
# MonthlyCharges                               0.441529          0.482607  ...
# TotalCharges                                 0.510100          0.522881  ...
# Churn                                       -0.082307         -0.066193  ...
# InternetService_DSL                          0.156765          0.145150  ...
# InternetService_Fiber optic                  0.165940          0.176356  ...
# Contract_Month-to-month                     -0.164393         -0.225988  ...
# Contract_One year                            0.084113          0.102911  ...
# PaymentMethod_Bank transfer (automatic)      0.086942          0.083047  ...
# PaymentMethod_Credit card (automatic)        0.090455          0.111252  ...
# PaymentMethod_Electronic check              -0.000364         -0.003308  ...
#
#                                          MonthlyCharges  TotalCharges  \
# gender                                        -0.013779      0.000048
# SeniorCitizen                                  0.219874      0.102411
# Partner                                        0.097825      0.319072
# Dependents                                    -0.112343      0.064653
# tenure                                         0.246862      0.825880
# PhoneService                                   0.248033      0.113008
# MultipleLines                                  0.490912      0.469042
# OnlineSecurity                                 0.296447      0.412619
# OnlineBackup                                   0.441529      0.510100
# DeviceProtection                               0.482607      0.522881
# TechSupport                                    0.338301      0.432868
# StreamingTV                                    0.629668      0.515709
# StreamingMovies                                0.627235      0.519867
# PaperlessBilling                               0.351930      0.157830
# MonthlyCharges                                 1.000000      0.651065
# TotalCharges                                   0.651065      1.000000
# Churn                                          0.192858     -0.199484
# InternetService_DSL                           -0.161368     -0.052190
# InternetService_Fiber optic                    0.787195      0.360769
# Contract_Month-to-month                        0.058933     -0.446776
# Contract_One year                              0.004810      0.170569
# PaymentMethod_Bank transfer (automatic)        0.042410      0.186119
# PaymentMethod_Credit card (automatic)          0.030055      0.182663
# PaymentMethod_Electronic check                 0.271117     -0.060436
#
#                                             Churn  InternetService_DSL  \
# gender                                  -0.008545             0.007584
# SeniorCitizen                            0.150541            -0.108276
# Partner                                 -0.149982            -0.001043
# Dependents                              -0.163128             0.051593
# tenure                                  -0.354049             0.013786
# PhoneService                             0.011691            -0.452255
# MultipleLines                            0.040033            -0.200318
# OnlineSecurity                          -0.171270             0.320343
# OnlineBackup                            -0.082307             0.156765
# DeviceProtection                        -0.066193             0.145150
# TechSupport                             -0.164716             0.312183
# StreamingTV                              0.063254             0.014973
# StreamingMovies                          0.060860             0.025623
# PaperlessBilling                         0.191454            -0.063390
# MonthlyCharges                           0.192858            -0.161368
# TotalCharges                            -0.199484            -0.052190
# Churn                                    1.000000            -0.124141
# InternetService_DSL                     -0.124141             1.000000
# InternetService_Fiber optic              0.307463            -0.641636
# Contract_Month-to-month                  0.404565            -0.065226
# Contract_One year                       -0.178225             0.047300
# PaymentMethod_Bank transfer (automatic) -0.118136             0.024760
# PaymentMethod_Credit card (automatic)   -0.134687             0.051222
# PaymentMethod_Electronic check           0.301455            -0.104293
#
#                                          InternetService_Fiber optic  \
# gender                                                     -0.011189
# SeniorCitizen                                               0.254923
# Partner                                                     0.001235
# Dependents                                                 -0.164101
# tenure                                                      0.017930
# PhoneService                                                0.290183
# MultipleLines                                               0.366420
# OnlineSecurity                                             -0.030506
# OnlineBackup                                                0.165940
# DeviceProtection                                            0.176356
# TechSupport                                                -0.020299
# StreamingTV                                                 0.329744
# StreamingMovies                                             0.322457
# PaperlessBilling                                            0.326470
# MonthlyCharges                                              0.787195
# TotalCharges                                                0.360769
# Churn                                                       0.307463
# InternetService_DSL                                        -0.641636
# InternetService_Fiber optic                                 1.000000
# Contract_Month-to-month                                     0.243014
# Contract_One year                                          -0.076809
# PaymentMethod_Bank transfer (automatic)                    -0.022779
# PaymentMethod_Credit card (automatic)                      -0.050552
# PaymentMethod_Electronic check                              0.335763
#
#                                          Contract_Month-to-month  \
# gender                                                 -0.003251
# SeniorCitizen                                           0.137752
# Partner                                                -0.280202
# Dependents                                             -0.229715
# tenure                                                 -0.649346
# PhoneService                                           -0.001243
# MultipleLines                                          -0.088558
# OnlineSecurity                                         -0.246844
# OnlineBackup                                           -0.164393
# DeviceProtection                                       -0.225988
# TechSupport                                            -0.285491
# StreamingTV                                            -0.112550
# StreamingMovies                                        -0.117867
# PaperlessBilling                                        0.168296
# MonthlyCharges                                          0.058933
# TotalCharges                                           -0.446776
# Churn                                                   0.404565
# InternetService_DSL                                    -0.065226
# InternetService_Fiber optic                             0.243014
# Contract_Month-to-month                                 1.000000
# Contract_One year                                      -0.570053
# PaymentMethod_Bank transfer (automatic)                -0.180159
# PaymentMethod_Credit card (automatic)                  -0.204960
# PaymentMethod_Electronic check                          0.330879
#
#                                          Contract_One year  \
# gender                                            0.007755
# SeniorCitizen                                    -0.046491
# Partner                                           0.083067
# Dependents                                        0.069222
# tenure                                            0.202338
# PhoneService                                     -0.003142
# MultipleLines                                    -0.003594
# OnlineSecurity                                    0.100658
# OnlineBackup                                      0.084113
# DeviceProtection                                  0.102911
# TechSupport                                       0.096258
# StreamingTV                                       0.061930
# StreamingMovies                                   0.064780
# PaperlessBilling                                 -0.052278
# MonthlyCharges                                    0.004810
# TotalCharges                                      0.170569
# Churn                                            -0.178225
# InternetService_DSL                               0.047300
# InternetService_Fiber optic                      -0.076809
# Contract_Month-to-month                          -0.570053
# Contract_One year                                 1.000000
# PaymentMethod_Bank transfer (automatic)           0.057629
# PaymentMethod_Credit card (automatic)             0.067590
# PaymentMethod_Electronic check                   -0.109546
#
#                                          PaymentMethod_Bank transfer (automatic)  \
# gender                                                                 -0.015973
# SeniorCitizen                                                          -0.016235
# Partner                                                                 0.111406
# Dependents                                                              0.052369
# tenure                                                                  0.243822
# PhoneService                                                            0.008271
# MultipleLines                                                           0.075429
# OnlineSecurity                                                          0.094366
# OnlineBackup                                                            0.086942
# DeviceProtection                                                        0.083047
# TechSupport                                                             0.100472
# StreamingTV                                                             0.046121
# StreamingMovies                                                         0.048755
# PaperlessBilling                                                       -0.017469
# MonthlyCharges                                                          0.042410
# TotalCharges                                                            0.186119
# Churn                                                                  -0.118136
# InternetService_DSL                                                     0.024760
# InternetService_Fiber optic                                            -0.022779
# Contract_Month-to-month                                                -0.180159
# Contract_One year                                                       0.057629
# PaymentMethod_Bank transfer (automatic)                                 1.000000
# PaymentMethod_Credit card (automatic)                                  -0.278423
# PaymentMethod_Electronic check                                         -0.377270
#
#                                          PaymentMethod_Credit card (automatic)  \
# gender                                                                0.001632
# SeniorCitizen                                                        -0.024359
# Partner                                                               0.082327
# Dependents                                                            0.061134
# tenure                                                                0.232800
# PhoneService                                                         -0.006916
# MultipleLines                                                         0.060319
# OnlineSecurity                                                        0.115473
# OnlineBackup                                                          0.090455
# DeviceProtection                                                      0.111252
# TechSupport                                                           0.117024
# StreamingTV                                                           0.040010
# StreamingMovies                                                       0.048398
# PaperlessBilling                                                     -0.013726
# MonthlyCharges                                                        0.030055
# TotalCharges                                                          0.182663
# Churn                                                                -0.134687
# InternetService_DSL                                                   0.051222
# InternetService_Fiber optic                                          -0.050552
# Contract_Month-to-month                                              -0.204960
# Contract_One year                                                     0.067590
# PaymentMethod_Bank transfer (automatic)                              -0.278423
# PaymentMethod_Credit card (automatic)                                 1.000000
# PaymentMethod_Electronic check                                       -0.373978
#
#                                          PaymentMethod_Electronic check
# gender                                                         0.000844
# SeniorCitizen                                                  0.171322
# Partner                                                       -0.083207
# Dependents                                                    -0.149274
# tenure                                                        -0.210197
# PhoneService                                                   0.002747
# MultipleLines                                                  0.083583
# OnlineSecurity                                                -0.112295
# OnlineBackup                                                  -0.000364
# DeviceProtection                                              -0.003308
# TechSupport                                                   -0.114807
# StreamingTV                                                    0.144747
# StreamingMovies                                                0.137420
# PaperlessBilling                                               0.208427
# MonthlyCharges                                                 0.271117
# TotalCharges                                                  -0.060436
# Churn                                                          0.301455
# InternetService_DSL                                           -0.104293
# InternetService_Fiber optic                                    0.335763
# Contract_Month-to-month                                        0.330879
# Contract_One year                                             -0.109546
# PaymentMethod_Bank transfer (automatic)                       -0.377270
# PaymentMethod_Credit card (automatic)                         -0.373978
# PaymentMethod_Electronic check                                 1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# Doesn't help, jsut the other way around, without htis parametrs 0.81 accuracy, with 0.85

# %%
# df2.drop(['gender', 'PhoneService', 'MultipleLines', 'OnlineBackup', 'DeviceProtection', 
#           'StreamingTV', 'StreamingMovies'], axis='columns', inplace=True)

# %%
scaler = MinMaxScaler()
cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])
df2.sample(5)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 401        0              0        0           0  0.140845             1
# 1628       0              1        1           0  0.408451             1
# 3805       1              1        0           0  0.000000             1
# 2157       1              0        1           0  0.704225             1
# 6430       0              0        1           1  0.211268             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 401               0               0             0                 0  ...
# 1628              1               0             1                 0  ...
# 3805              0               0             0                 0  ...
# 2157              1               0             1                 1  ...
# 6430              0               0             0                 0  ...
#
#       MonthlyCharges  TotalCharges  Churn  InternetService_DSL  \
# 401         0.017910      0.025260      0                False
# 1628        0.714428      0.300992      0                False
# 3805        0.531343      0.006099      1                False
# 2157        0.881095      0.632356      0                False
# 6430        0.010945      0.029668      0                False
#
#       InternetService_Fiber optic  Contract_Month-to-month  Contract_One year  \
# 401                         False                    False               True
# 1628                         True                     True              False
# 3805                         True                     True              False
# 2157                         True                    False               True
# 6430                        False                     True              False
#
#       PaymentMethod_Bank transfer (automatic)  \
# 401                                     False
# 1628                                    False
# 3805                                    False
# 2157                                     True
# 6430                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check
# 401                                    True                           False
# 1628                                  False                            True
# 3805                                  False                            True
# 2157                                  False                           False
# 6430                                  False                           False
#
# [5 rows x 24 columns]

# %%
bool_cols = ['InternetService_DSL', 'InternetService_Fiber optic', 'Contract_Month-to-month',
             'Contract_One year','PaymentMethod_Bank transfer (automatic)','PaymentMethod_Credit card (automatic)',
             'PaymentMethod_Electronic check']

for col in bool_cols:
    df2[col] = df2[col].astype(np.uint8)

df2.dtypes
# Out:
# gender                                       uint8
# SeniorCitizen                                int64
# Partner                                      uint8
# Dependents                                   uint8
# tenure                                     float64
# PhoneService                                 uint8
# MultipleLines                                uint8
# OnlineSecurity                               uint8
# OnlineBackup                                 uint8
# DeviceProtection                             uint8
# TechSupport                                  uint8
# StreamingTV                                  uint8
# StreamingMovies                              uint8
# PaperlessBilling                             uint8
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        uint8
# InternetService_DSL                          uint8
# InternetService_Fiber optic                  uint8
# Contract_Month-to-month                      uint8
# Contract_One year                            uint8
# PaymentMethod_Bank transfer (automatic)      uint8
# PaymentMethod_Credit card (automatic)        uint8
# PaymentMethod_Electronic check               uint8
# dtype: object

# %%
X = df2.drop('Churn', axis='columns')
y = df2['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, )

# %%
X.shape, len(X_train.columns)
# Out:
# ((7032, 23), 23)

# %%
tf.convert_to_tensor(X)
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(X)
normalizer(X.iloc[:3])
# Out:
# <tf.Tensor: shape=(3, 23), dtype=float32, numpy=
# array([[-1.00943   , -0.4403272 ,  1.0356174 , -0.65230507, -1.2802479 ,
#         -3.0563338 , -0.85433567, -0.6337462 ,  1.3783301 , -0.7239179 ,
#         -0.63926077, -0.7901861 , -0.7968493 ,  0.8289396 , -1.1616944 ,
#         -0.99419373,  1.3822432 , -0.88689667,  0.90261275, -0.51453686,
#         -0.52997583, -0.5253511 ,  1.4047638 ],
#        [ 0.99065834, -0.4403272 , -0.9656084 , -0.65230507,  0.06430303,
#          0.32718867, -0.85433567,  1.5779184 , -0.7255156 ,  1.3813723 ,
#         -0.63926077, -0.7901861 , -0.7968493 , -1.2063605 , -0.26087826,
#         -0.17373917,  1.3822432 , -0.88689667, -1.1078944 ,  1.9434966 ,
#         -0.52997583, -0.5253511 , -0.7118634 ],
#        [ 0.99065834, -0.4403272 , -0.9656084 , -0.65230507, -1.2395039 ,
#          0.32718867, -0.85433567,  1.5779184 ,  1.3783301 , -0.7239179 ,
#         -0.63926077, -0.7901861 , -0.7968493 ,  0.8289396 , -0.3639236 ,
#         -0.9596487 ,  1.3822432 , -0.88689667,  0.90261275, -0.51453686,
#         -0.52997583, -0.5253511 , -0.7118634 ]], dtype=float32)>

# %%
model = keras.Sequential([
    normalizer,
    keras.layers.Dense(len(X_train.columns), activation='relu'),
    keras.layers.Dense(13, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 154/154 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7174
# Epoch 2/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.7895
# Epoch 3/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4309 - accuracy: 0.7944
# Epoch 4/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.8007
# Epoch 5/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4173 - accuracy: 0.8019
# Epoch 6/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4139 - accuracy: 0.8046
# Epoch 7/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.4101 - accuracy: 0.8066
# Epoch 8/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4077 - accuracy: 0.8054
# Epoch 9/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4056 - accuracy: 0.8080
# Epoch 10/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4023 - accuracy: 0.8125
# Epoch 11/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.4012 - accuracy: 0.8131
# Epoch 12/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8090
# Epoch 13/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3982 - accuracy: 0.8143
# Epoch 14/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8141
# Epoch 15/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8165
# Epoch 16/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8182
# Epoch 17/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3926 - accuracy: 0.8149
# Epoch 18/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3905 - accuracy: 0.8188
# Epoch 19/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3893 - accuracy: 0.8176
# Epoch 20/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3884 - accuracy: 0.8210
# Epoch 21/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3874 - accuracy: 0.8208
# Epoch 22/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8226
# Epoch 23/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3844 - accuracy: 0.8253
# Epoch 24/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3828 - accuracy: 0.8216
# Epoch 25/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3824 - accuracy: 0.8245
# Epoch 26/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8261
# Epoch 27/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3804 - accuracy: 0.8265
# Epoch 28/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3796 - accuracy: 0.8281
# Epoch 29/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3779 - accuracy: 0.8273
# Epoch 30/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3766 - accuracy: 0.8291
# Epoch 31/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3758 - accuracy: 0.8283
# Epoch 32/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3744 - accuracy: 0.8279
# Epoch 33/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.8281
# Epoch 34/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3735 - accuracy: 0.8275
# Epoch 35/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3722 - accuracy: 0.8322
# Epoch 36/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3719 - accuracy: 0.8310
# Epoch 37/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3706 - accuracy: 0.8289
# Epoch 38/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3704 - accuracy: 0.8306
# Epoch 39/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3693 - accuracy: 0.8336
# Epoch 40/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3679 - accuracy: 0.8328
# Epoch 41/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3681 - accuracy: 0.8306
# Epoch 42/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3665 - accuracy: 0.8336
# Epoch 43/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3656 - accuracy: 0.8356
# Epoch 44/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3651 - accuracy: 0.8328
# Epoch 45/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3645 - accuracy: 0.8342
# Epoch 46/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3630 - accuracy: 0.8318
# Epoch 47/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8385
# Epoch 48/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3621 - accuracy: 0.8354
# Epoch 49/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.8344
# Epoch 50/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3609 - accuracy: 0.8379
# Epoch 51/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3604 - accuracy: 0.8344
# Epoch 52/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3598 - accuracy: 0.8371
# Epoch 53/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3585 - accuracy: 0.8362
# Epoch 54/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3591 - accuracy: 0.8348
# Epoch 55/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3568 - accuracy: 0.8373
# Epoch 56/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3568 - accuracy: 0.8379
# Epoch 57/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3557 - accuracy: 0.8371
# Epoch 58/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3550 - accuracy: 0.8379
# Epoch 59/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3558 - accuracy: 0.8385
# Epoch 60/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3544 - accuracy: 0.8354
# Epoch 61/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3538 - accuracy: 0.8377
# Epoch 62/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3525 - accuracy: 0.8399
# Epoch 63/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3524 - accuracy: 0.8397
# Epoch 64/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8383
# Epoch 65/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8387
# Epoch 66/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8385
# Epoch 67/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8381
# Epoch 68/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3499 - accuracy: 0.8381
# Epoch 69/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3483 - accuracy: 0.8391
# Epoch 70/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3486 - accuracy: 0.8411
# Epoch 71/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3482 - accuracy: 0.8397
# Epoch 72/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3475 - accuracy: 0.8389
# Epoch 73/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3466 - accuracy: 0.8401
# Epoch 74/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3462 - accuracy: 0.8413
# Epoch 75/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3460 - accuracy: 0.8391
# Epoch 76/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3450 - accuracy: 0.8417
# Epoch 77/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3446 - accuracy: 0.8434
# Epoch 78/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3449 - accuracy: 0.8405
# Epoch 79/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3423 - accuracy: 0.8438
# Epoch 80/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8444
# Epoch 81/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8436
# Epoch 82/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3418 - accuracy: 0.8436
# Epoch 83/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8452
# Epoch 84/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3406 - accuracy: 0.8450
# Epoch 85/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3401 - accuracy: 0.8425
# Epoch 86/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3398 - accuracy: 0.8456
# Epoch 87/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3403 - accuracy: 0.8442
# Epoch 88/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.8456
# Epoch 89/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3394 - accuracy: 0.8450
# Epoch 90/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3382 - accuracy: 0.8472
# Epoch 91/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3381 - accuracy: 0.8478
# Epoch 92/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3371 - accuracy: 0.8468
# Epoch 93/100
# 154/154 [==============================] - 0s 2ms/step - loss: 0.3370 - accuracy: 0.8472
# Epoch 94/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3358 - accuracy: 0.8501
# Epoch 95/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3372 - accuracy: 0.8456
# Epoch 96/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3351 - accuracy: 0.8492
# Epoch 97/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3347 - accuracy: 0.8488
# Epoch 98/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3357 - accuracy: 0.8484
# Epoch 99/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3352 - accuracy: 0.8499
# Epoch 100/100
# 154/154 [==============================] - 0s 1ms/step - loss: 0.3338 - accuracy: 0.8482

# %%
yp = model.predict(X_test)
y_pred = []

for ans in yp:
    if ans > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

y_pred[10:20], y_test[10:20]
# Out:
# 66/66 [==============================] - 0s 730us/step
# ([1, 1, 0, 0, 0, 0, 1, 1, 0, 0],
#  4232    1
#  3426    1
#  1100    0
#  2193    0
#  1413    0
#  2832    0
#  1148    1
#  1645    1
#  3819    0
#  1443    0
#  Name: Churn, dtype: uint8)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      1589
#            1       0.55      0.54      0.54       521
#
#     accuracy                           0.78      2110
#    macro avg       0.70      0.70      0.70      2110
# weighted avg       0.78      0.78      0.78      2110

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
